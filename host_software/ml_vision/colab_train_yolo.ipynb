# %% [markdown]
# # VRI 2026 - YOLOv8 Synthetic Marker Tracker
#
# This notebook clones the repository, extracts the uploaded `03_synthetic_yolo.zip` dataset, and trains YOLOv8 on it.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !rm -rf /content/ball_balance_video_controlled
# !git clone https://github.com/Jack0468/ball_balance_video_controlled.git
# !pip install ultralytics opencv-python-headless pandas numpy albumentations
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# Unzip the synthetic dataset (assuming you uploaded it to Google Drive as 03_synthetic_yolo.zip)
# !mkdir -p /content/ball_balance_video_controlled/host_software/ml_vision/data/03_synthetic_yolo
# !unzip -q /content/drive/MyDrive/03_synthetic_yolo.zip -d /content/ball_balance_video_controlled/host_software/ml_vision/data/
print("Synthetic dataset unzipped!")

# %%
# Run the YOLOv8 training script
# %cd /content/ball_balance_video_controlled/host_software/ml_vision
# !python training/train_yolo.py --data_dir data/03_synthetic_yolo

# %%
# Copy the saved YOLO models back to your Google Drive
# !mkdir -p /content/drive/MyDrive/VRI_Models
# !cp -r /content/ball_balance_video_controlled/host_software/ml_vision/models/yolov8_marker_and_ball_detector /content/drive/MyDrive/VRI_Models/
print("YOLO Models backed up to Google Drive!")
