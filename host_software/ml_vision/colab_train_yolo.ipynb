# %% [markdown]
# # VRI 2026 - YOLOv8 Synthetic Marker Tracker
#
# This notebook clones the repository, extracts the uploaded `03_synthetic_yolo.zip` dataset, and trains YOLOv8 on it.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !rm -rf /content/ball_balance_video_controlled
# !git clone https://github.com/Jack0468/ball_balance_video_controlled.git
# !pip install ultralytics opencv-python-headless pandas numpy albumentations
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# Unzip the unified pose dataset
# !mkdir -p /content/ball_balance_video_controlled/host_software/ml_vision/data/02_silver_unified_pose
# !unzip -q -o /content/drive/MyDrive/02_silver_unified_pose.zip -d /content/ball_balance_video_controlled/host_software/ml_vision/data/
# Handle potential nested folders from zipping
# !if [ -d "/content/ball_balance_video_controlled/host_software/ml_vision/data/02_silver_unified_pose/02_silver_unified_pose" ]; then mv /content/ball_balance_video_controlled/host_software/ml_vision/data/02_silver_unified_pose/02_silver_unified_pose/* /content/ball_balance_video_controlled/host_software/ml_vision/data/02_silver_unified_pose/; fi
print("Unified Pose dataset unzipped!")

# %%
# Run the YOLOv8-Pose training script
# %cd /content/ball_balance_video_controlled/host_software/ml_vision
# !python training/train_yolo.py --data_dir data/02_silver_unified_pose --save_dir /content/drive/MyDrive/VRI_Models
