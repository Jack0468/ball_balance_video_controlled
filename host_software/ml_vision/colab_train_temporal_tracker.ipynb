# %% [markdown]
# # Train Temporal Expert Tracker (ResNet18 + LSTM)
# This notebook clones the repository from a fresh start, extracts `vri_2026_data.zip`, and trains the Temporal Expert Tracker.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !rm -rf /content/ball_balance_video_controlled
# !git clone https://github.com/Jack0468/ball_balance_video_controlled.git
# !pip install pandas Pillow torch torchvision
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# Unzip the raw telemetry data
# !mkdir -p /content/ball_balance_video_controlled/host_software/ml_vision/data
# !unzip -q -o /content/drive/MyDrive/vri_2026_data.zip -d /content/ball_balance_video_controlled/host_software/ml_vision/data/02_silver
print("Raw data unzipped!")

# %% [markdown]
# ### Dataset Preprocessing
# Deduplicate the telemetry so the LSTM processes a true 30fps chronological sequence.

# %%
# %cd /content/ball_balance_video_controlled/host_software/ml_vision/data_processing
# !python clean_sequential_dataset.py --data_dir ../data/02_silver

# %% [markdown]
# ### Training

# %%
# %cd /content/ball_balance_video_controlled/host_software/ml_vision/training
# !python train_temporal_tracker.py

# %%
# Copy the saved temporal models back to your Google Drive
# !mkdir -p /content/drive/MyDrive/VRI_Models
# !cp -r /content/ball_balance_video_controlled/host_software/ml_vision/models/temporal_expert_tracker /content/drive/MyDrive/VRI_Models/
print("Temporal Models backed up to Google Drive!")
