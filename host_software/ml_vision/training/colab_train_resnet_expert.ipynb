# %% [markdown]
# # Train ResNet Expert Tracker
# This notebook clones the repository, extracts the dataset from your Google Drive, and trains the ResNet-based Expert Tracker using Spatial Softmax.

# %%
SESSION_NAME = 'session_20260728_102908'
VERSION = 'v1'
ARCH = 'resnet18'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !rm -rf /content/ball_balance_video_controlled
# !git clone https://github.com/Jack0468/ball_balance_video_controlled.git
# !pip install pandas Pillow torch torchvision
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# Unzip the raw telemetry data
# !mkdir -p /content/ball_balance_video_controlled/host_software/data
# !unzip -q -o /content/drive/MyDrive/{SESSION_NAME}.zip -d /content/ball_balance_video_controlled/host_software/data/02_silver
print("Raw data unzipped!")

# %% [markdown]
# ### Training

# %%
# %cd /content/ball_balance_video_controlled
# !python host_software/ml_vision/training/train_resnet_expert_tracker.py \
    --data_dir host_software/data/02_silver/{SESSION_NAME} \
    --save_dir /content/drive/MyDrive/VRI_Models \
    --arch {ARCH} \
    --version {VERSION}

# %% [markdown]
# ### Evaluation

# %%
# !python host_software/ml_vision/evaluations/evaluate_resnet_expert_tracker.py \
    --data_dir host_software/data/02_silver/{SESSION_NAME} \
    --model_path /content/drive/MyDrive/VRI_Models/{ARCH}_expert_tracker_{VERSION}/expert_tracker_best.pth \
    --arch {ARCH}
